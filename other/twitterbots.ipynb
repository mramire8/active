# %%
import json
import simplejson

data_path = 'C:/Users/mramire8/Documents/Datasets/twitter'

f = open(data_path + "/good.json")

i = 0
tot = 0
for line in f:
    user = line.split("]][[")
    print user[0]
    last = len(user)
    print "Total %s users" % last
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-a8d4abc7cc8c> in <module>()
#      16 #             print tweets[544928-5:544928+5]
#      17         if i == 0:
# ---> 18             t = json.loads(tweets[1:])
#      19         elif i == (last-1):
#      20             t = json.loads(tweets[:-2])
#
# C:\Python27\lib\json\__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     336             parse_int is None and parse_float is None and
#     337             parse_constant is None and object_pairs_hook is None and not kw):
# --> 338         return _default_decoder.decode(s)
#     339     if cls is None:
#     340         cls = JSONDecoder
#
# C:\Python27\lib\json\decoder.pyc in decode(self, s, _w)
#     364
#     365         """
# --> 366         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     367         end = _w(s, end).end()
#     368         if end != len(s):
#
# C:\Python27\lib\json\decoder.pyc in raw_decode(self, s, idx)
#     380         """
#     381         try:
# --> 382             obj, end = self.scan_once(s, idx)
#     383         except StopIteration:
#     384             raise ValueError("No JSON object could be decoded")
#
# ValueError: Expecting object: line 1 column 542293 (char 542292)
# [[{"contributors": null, "truncated": false, "text": "And this one comes from the library\u2026\n\nSix hard-cover volumes from the Collected Works of Hugh Nibley and a... http://t.co/XOp6o7MhWL", "in_reply_to_status_id": null, "id": 527212032597037056, "favorite_count": 0, "source": "<a href=\"http://www.facebook.com/twitter\" rel=\"nofollow\">Facebook</a>", "retweeted": false, "coordinates": null, "entities": {"symbols": [], "user_mentions": [], "hashtags": [], "urls": [{"url": "http://t.co/XOp6o7MhWL", "indices": [110, 132], "expanded_url": "http://fb.me/6B2ibP2Wo", "display_url": "fb.me/6B2ibP2Wo"}]}, "in_reply_to_screen_name": null, "id_str": "527212032597037056", "retweet_count": 0, "in_reply_to_user_id": null, "favorited": false, "user": {"follow_request_sent": false, "profile_use_background_image": false, "profile_text_color": "666666", "default_profile_image": false, "id": 614, "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme9/bg.gif", "verified": false, "profile_location": null, "profile_image_url_https": "https://pbs.twimg.com/profile_images/465965547855679488/ONqxqGvL_normal.jpeg", "profile_sidebar_fill_color": "252429", "entities": {"url": {"urls": [{"url": "http://t.co/x5Vr8HWFxj", "indices": [0, 22], "expanded_url": "http://facebook.com/christian.harrison", "display_url": "facebook.com/christian.harr\u2026"}]}, "description": {"urls": []}}, "followers_count": 1377, "profile_sidebar_border_color": "000000", "id_str": "614", "profile_background_color": "1A1B1F", "listed_count": 39, "is_translation_enabled": false, "utc_offset": 12600, "statuses_count": 7894, "description": "Urban enthusiast, professional storyteller, man of faith.", "friends_count": 1931, "location": "Salt Lake City, UT", "profile_link_color": "2FC2EF", "profile_image_url": "http://pbs.twimg.com/profile_images/465965547855679488/ONqxqGvL_normal.jpeg", "following": false, "geo_enabled": true, "profile_banner_url": "https://pbs.twimg.com/profile_banners/614/1365311832", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme9/bg.gif", "name": "Christian Harrison", "lang": "en", "profile_background_tile": false, "favourites_count": 83, "screen_name": "dcharrison", "notifications": false, "url": "http://t.co/x5Vr8HWFxj", "created_at": "Thu Jul 13 20:30:05 +0000 2006", "contributors_enabled": false, "time_zone": "Tehran", "protected": false, "default_profile": false, "is_translator": false}, "geo": null, "in_reply_to_user_id_str": null, "possibly_sensitive": false, "lang": "en", "created_at": "Tue Oct 28 21:35:18 +0000 2014", "in_reply_to_status_id_str": null, "place": null}, {"contributors": null, "truncated": false, "text": "Another round of house-cleaning treasure!\n\nI have a vintage ceramic Japanese headrest (mid-twentieth century) for... http://t.co/Y9I6Su3m0z", "in_reply_to_status_id": null, "id": 527210737530195968, "favorite_count": 0, "source": "<a href=\"http://www.facebook.com/twitter\" rel=\"nofollow\">Facebook</a>", "retweeted": false, "coordinates": null, "entities": {"symbols": [], "user_mentions": [], "hashtags": [], "urls": [{"url": "http://t.co/Y9I6Su3m0z", "indices": [117, 139], "expanded_url": "http://fb.me/6VPTwWGbo", "display_url": "fb.me/6VPTwWGbo"}]}, "in_reply_to_screen_name": null, "id_str": "527210737530195968", "retweet_count": 0, "in_reply_to_user_id": null, "favorited": false, "user": {"follow_request_sent": false, "profile_use_background_image": false, "profile_text_color": "666666", "default_profile_image": false, "id": 614, "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme9/bg.gif", "verified": false, "profile_location": null, "profile_image_url_https": "https://pbs.twimg.com/profile_images/465965547855679488/ONqxqGvL_normal.jpeg", "profile_sidebar_fill_color": "252429", "entities": {"url": {"urls": [{"url": "http://t.co/x5Vr8HWFxj", "indices": [0, 22], "expanded_url": "http://facebook.com/christian.harrison", "display_url": "facebook.com/c ...
# Total 883 users

# %%
import ast
print len(line.split("]["))
# list_all = ast.literal_eval(line)
print len(list_all)
print user[1][:10], user[1][-15:]
print user[2][:10], user[2][-15:]
print user[3][:10], user[3][-15:]
print user[-1][:10], user[-1][-15:]
print user[0][:10], user[0][-15:]
# obj = json.loads(user[0][1:] + "]")
# obj = json.loads(user[1])
# print len(obj)
# print type(obj[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-8ea6d4f49428> in <module>()
#       2 print len(line.split("]["))
#       3 # list_all = ast.literal_eval(line)
# ----> 4 print len(list_all)
#       5 print user[1][:10], user[1][-15:]
#       6 print user[2][:10], user[2][-15:]
#
# NameError: name 'list_all' is not defined
# 1098

# %%
good = []
for i,tweets in enumerate(user):
#         if i == 165:
#             print tweets[544928-5:544928+5]
        if i == 0:
            t = json.loads(tweets[1:] + "]")
        elif i == (last-1):
            t = json.loads("["+tweets[:-1])
        else:
            t = json.loads("["+tweets+"]")
        good.append(t)
        print "User %s, tweets %s" % (i, len(t))
import pickle
# Out:
# User 0, tweets 200
# User 1, tweets 200
# User 2, tweets 200
# User 3, tweets 199
# User 4, tweets 200
# User 5, tweets 200
# User 6, tweets 200
# User 7, tweets 200
# User 8, tweets 200
# User 9, tweets 200
# User 10, tweets 200
# User 11, tweets 200
# User 12, tweets 199
# User 13, tweets 200
# User 14, tweets 200
# User 15, tweets 199
# User 16, tweets 200
# User 17, tweets 200
# User 18, tweets 200
# User 19, tweets 200
# User 20, tweets 200
# User 21, tweets 200
# User 22, tweets 200
# User 23, tweets 200
# User 24, tweets 200
# User 25, tweets 199
# User 26, tweets 199
# User 27, tweets 196
# User 28, tweets 200
# User 29, tweets 200
# User 30, tweets 200
# User 31, tweets 197
# User 32, tweets 200
# User 33, tweets 198
# User 34, tweets 200
# User 35, tweets 200
# User 36, tweets 200
# User 37, tweets 200
# User 38, tweets 200
# User 39, tweets 200
# User 40, tweets 200
# User 41, tweets 200
# User 42, tweets 200
# User 43, tweets 200
# User 44, tweets 198
# User 45, tweets 200
# User 46, tweets 200
# User 47, tweets 200
# User 48, tweets 200
# User 49, tweets 200
# User 50, tweets 127
# User 51, tweets 200
# User 52, tweets 199
# User 53, tweets 200
# User 54, tweets 200
# User 55, tweets 200
# User 56, tweets 200
# User 57, tweets 200
# User 58, tweets 200
# User 59, tweets 200
# User 60, tweets 199
# User 61, tweets 200
# User 62, tweets 200
# User 63, tweets 200
# User 64, tweets 199
# User 65, tweets 200
# User 66, tweets 200
# User 67, tweets 200
# User 68, tweets 200
# User 69, tweets 200
# User 70, tweets 200
# User 71, tweets 200
# User 72, tweets 200
# User 73, tweets 200
# User 74, tweets 199
# User 75, tweets 200
# User 76, tweets 200
# User 77, tweets 199
# User 78, tweets 200
# User 79, tweets 199
# User 80, tweets 200
# User 81, tweets 198
# User 82, tweets 200
# User 83, tweets 200
# User 84, tweets 200
# User 85, tweets 200
# User 86, tweets 200
# User 87, tweets 200
# User 88, tweets 199
# User 89, tweets 200
# User 90, tweets 200
# User 91, tweets 200
# User 92, tweets 200
# User 93, tweets 199
# User 94, tweets 197
# User 95, tweets 200
# User 96, tweets 200
# User 97, tweets 200
# User 98, tweets 198
# User 99, tweets 200
# User 100, tweets 200
# User 101, tweets 200
# User 102, tweets 200
# User 103, tweets 200
# User 104, tweets 200
# User 105, tweets 199
# User 106, tweets 200
# User 107, tweets 200
# User 108, tweets 200
# User 109, tweets 200
# User 110, tweets 200
# User 111, tweets 198
# User 112, tweets 200
# User 113, tweets 198
# User 114, tweets 200
# User 115, tweets 200
# User 116, tweets 200
# User 117, tweets 200
# User 118, tweets 200
# User 119, tweets 200
# User 120, tweets 200
# User 121, tweets 200
# User 122, tweets 200
# User 123, tweets 200
# User 124, tweets 200
# User 125, tweets 200
# User 126, tweets 200
# User 127, tweets 199
# User 128, tweets 200
# User 129, tweets 200
# User 130, tweets 200
# User 131, tweets 200
# User 132, tweets 200
# User 133, tweets 199
# User 134, tweets 200
# User 135, tweets 199
# User 136, tweets 200
# User 137, tweets 200
# User 138, tweets 199
# User 139, tweets 200
# User 140, tweets 200
# User 141, tweets 182
# User 142, tweets 200
# User 143, tweets 200
# User 144, tweets 200
# User 145, tweets 200
# User 146, tweets 200
# User 147, tweets 200
# User 148, tweets 200
# User 149, tweets 200
# User 150, tweets 200
# User 151, tweets 199
# User 152, tweets 200
# User 153, tweets 200
# User 154, tweets 200
# User 155, tweets 200
# User 156, tweets 200
# User 157, tweets 200
# User 158, tweets 200
# User 159, tweets 200
# User 160, tweets 199
# User 161, tweets 200
# User 162, tweets 200
# User 163, tweets 200
# User 164, tweets 199
# User 165, tweets 198
# User 166, tweets 199
# User 167, tweets 200
# User 168, tweets 200
# User 169, tweets 200
# User 170, tweets 200
# User 171, tweets 200
# User 172, tweets 200
# User 173, tweets 200
# User 174, tweets 200
# User 175, tweets 200
# User 176, tweets 200
# User 177, tweets 200
# User 178, tweets 200
# User 179, tweets 200
# User 180, tweets 200
# User 181, tweets 200
# User 182, tweets 199
# User 183, tweets 200
# User 184, tweets 200
# User 185, tweets 197
# User 186, tweets 200
# User 187, tweets 200
# User 188, tweets 200
# User 189, tweets 200
# User 190, tweets 200
# User 191, tweets 200
# User 192, tweets 200
# User 193, tweets 200
# User 194, tweets 200
# User 195, tweets 200
# User 196, tweets 200
# User 197, tweets 200
# User 198, tweets 200
# User 199, tweets 199
# User 200, tweets 200
# User 201, tweets 200
# User 202, tweets 200
# User 203, tweets 200
# User 204, tweets 200
# User 205, tweets 200
# User 206, tweets 200
# User 207, tweets 199
# User 208, tweets 200
# User 209, tweets 200
# User 210, tweets 200
# User 211, tweets 200
# User 212, tweets 195
# User 213, tweets 200
# User 214, tweets 200
# User 215, tweets 200
# User 216, tweets 200
# User 217, tweets 200
# User 218, tweets 200
# User 219, tweets 199
# User 220, tweets 200
# User 221, tweets 200
# User 222, tweets 200
# User 223, tweets 200
# User 224, tweets 200
# User 225, tweets 200
# User 226, tweets 200
# User 227, tweets 200
# User 228, tweets 200
# User 229, tweets 199
# User 230, tweets 200
# User 231, tweets 200
# User 232, tweets 196
# User 233, tweets 200
# User 234, tweets 200
# User 235, tweets 200
# User 236, tweets 199
# User 237, tweets 200
# User 238, tweets 200
# User 239, tweets 200
# User 240, tweets 200
# User 241, tweets 200
# User 242, tweets 197
# User 243, tweets 200
# User 244, tweets 200
# User 245, tweets 200
# User 246, tweets 199
# User 247, tweets 200
# User 248, tweets 200
# User 249, tweets 200
# User 250, tweets 200
# User 251, tweets 200
# User 252, tweets 199
# User 253, tweets 200
# User 254, tweets 199
# User 255, tweets 200
# User 256, tweets 200
# User 257, tweets 197
# User 258, tweets 200
# User 259, tweets 200
# User 260, tweets 200
# User 261, tweets 200
# User 262, tweets 200
# User 263, tweets 200
# User 264, tweets 200
# User 265, tweets 200
# User 266, tweets 200
# User 267, tweets 196
# User 268, tweets 200
# User 269, tweets 200
# User 270, tweets 200
# User 271, tweets 200
# User 272, tweets 200
# User 273, tweets 200
# User 274, tweets 200
# User 275, tweets 200
# User 276, tweets 198
# User 277, tweets 200
# User 278, tweets 200
# User 279, tweets 200
# User 280, tweets 200
# User 281, tweets 200
# User 282, tweets 200
# User 283, tweets 200
# User 284, tweets 200
# User 285, tweets 200
# User 286, tweets 200
# User 287, tweets 200
# User 288, tweets 200
# User 289, tweets 200
# User 290, tweets 200
# User 291, tweets 200
# User 292, tweets 199
# User 293, tweets 200
# User 294, tweets 200
# User 295, tweets 200
# User 296, tweets 200
# User 297, tweets 200
# User 298, tweets 198
# User 299, tweets 199
# User 300, tweets 200
# User 301, tweets 200
# User 302, tweets 200
# User 303, tweets 200
# User 304, tweets 200
# User 305, tweets 200
# User 306, tweets 200
# User 307, tweets 200
# User 308, tweets 200
# User 309, tweets 200
# User 310, tweets 200
# User 311, tweets 200
# User 312, tweets 200
# User 313, tweets 200
# User 314, tweets 200
# User 315, tweets 200
# User 316, tweets 200
# User 317, tweets 197
# User 318, tweets 200
# User 319, tweets 200
# User 320, tweets 200
# User 321, tweets 200
# User 322, tweets 200
# User 323, tweets 200
# User 324, tweets 200
# User 325, tweets 199
# User 326, tweets 200
# User 327, tweets 197
# User 328, tweets 200
# User 329, tweets 200
# User 330, tweets 200
# User 331, tweets 198
# User 332, tweets 199
# User 333, tweets 199
# User 334, tweets 200
# User 335, tweets 200
# User 336, tweets 200
# User 337, tweets 200
# User 338, tweets 200
# User 339, tweets 200
# User 340, tweets 200
# User 341, tweets 200
# User 342, tweets 200
# User 343, tweets 8
# User 344, tweets 199
# User 345, tweets 200
# User 346, tweets 200
# User 347, tweets 200
# User 348, tweets 200
# User 349, tweets 200
# User 350, tweets 200
# User 351, tweets 200
# User 352, tweets 200
# User 353, tweets 198
# User 354, tweets 198
# User 355, tweets 199
# User 356, tweets 200
# User 357, tweets 199
# User 358, tweets 200
# User 359, tweets 200
# User 360, tweets 197
# User 361, tweets 200
# User 362, tweets 200
# User 363, tweets 200
# User 364, tweets 200
# User 365, tweets 200
# User 366, tweets 200
# User 367, tweets 200
# User 368, tweets 200
# User 369, tweets 198
# User 370, tweets 200
# User 371, tweets 200
# User 372, tweets 200
# User 373, tweets 200
# User 374, tweets 200
# User 375, tweets 200
# User 376, tweets 200
# User 377, tweets 198
# User 378, tweets 200
# User 379, tweets 200
# User 380, tweets 200
# User 381, tweets 200
# User 382, tweets 198
# User 383, tweets 200
# User 384, tweets 200
# User 385, tweets 200
# User 386, tweets 101
# User 387, tweets 200
# User 388, tweets 200
# User 389, tweets 200
# User 390, tweets 200
# User 391, tweets 200
# User 392, tweets 200
# User 393, tweets 200
# User 394, tweets 200
# User 395, tweets 200
# User 396, tweets 200
# User 397, tweets 200
# User 398, tweets 200
# User 399, tweets 200
# User 400, tweets 200
# User 401, tweets 199
# User 402, tweets 200
# User 403, tweets 197
# User 404, tweets 200
# User 405, tweets 200
# User 406, tweets 200
# User 407, tweets 198
# User 408, tweets 199
# User 409, tweets 200
# User 410, tweets 200
# User 411, tweets 200
# User 412, tweets 200
# User 413, tweets 200
# User 414, tweets 200
# User 415, tweets 199
# User 416, tweets 200
# User 417, tweets 200
# User 418, tweets 200
# User 419, tweets 200
# User 420, tweets 200
# User 421, tweets 200
# User 422, tweets 200
# User 423, tweets 200
# User 424, tweets 200
# User 425, tweets 200
# User 426, tweets 200
# User 427, tweets 200
# User 428, tweets 200
# User 429, tweets 200
# User 430, tweets 200
# User 431, tweets 200
# User 432, tweets 200
# User 433, tweets 200
# User 434, tweets 200
# User 435, tweets 200
# User 436, tweets 200
# User 437, tweets 200
# User 438, tweets 200
# User 439, tweets 200
# User 440, tweets 200
# User 441, tweets 200
# User 442, tweets 200
# User 443, tweets 200
# User 444, tweets 200
# User 445, tweets 200
# User 446, tweets 200
# User 447, tweets 200
# User 448, tweets 200
# User 449, tweets 200
# User 450, tweets 199
# User 451, tweets 197
# User 452, tweets 200
# User 453, tweets 200
# User 454, tweets 198
# User 455, tweets 200
# User 456, tweets 200
# User 457, tweets 200
# User 458, tweets 198
# User 459, tweets 200
# User 460, tweets 199
# User 461, tweets 200
# User 462, tweets 200
# User 463, tweets 200
# User 464, tweets 200
# User 465, tweets 200
# User 466, tweets 200
# User 467, tweets 200
# User 468, tweets 200
# User 469, tweets 200
# User 470, tweets 200
# User 471, tweets 200
# User 472, tweets 200
# User 473, tweets 199
# User 474, tweets 200
# User 475, tweets 200
# User 476, tweets 200
# User 477, tweets 200
# User 478, tweets 200
# User 479, tweets 200
# User 480, tweets 200
# User 481, tweets 200
# User 482, tweets 198
# User 483, tweets 200
# User 484, tweets 200
# User 485, tweets 198
# User 486, tweets 200
# User 487, tweets 200
# User 488, tweets 200
# User 489, tweets 194
# User 490, tweets 200
# User 491, tweets 200
# User 492, tweets 198
# User 493, tweets 200
# User 494, tweets 200
# User 495, tweets 199
# User 496, tweets 194
# User 497, tweets 200
# User 498, tweets 200
# User 499, tweets 200
# User 500, tweets 200
# User 501, tweets 200
# User 502, tweets 200
# User 503, tweets 199
# User 504, tweets 200
# User 505, tweets 200
# User 506, tweets 200
# User 507, tweets 200
# User 508, tweets 200
# User 509, tweets 200
# User 510, tweets 200
# User 511, tweets 200
# User 512, tweets 200
# User 513, tweets 200
# User 514, tweets 200
# User 515, tweets 200
# User 516, tweets 200
# User 517, tweets 200
# User 518, tweets 200
# User 519, tweets 196
# User 520, tweets 200
# User 521, tweets 199
# User 522, tweets 197
# User 523, tweets 200
# User 524, tweets 198
# User 525, tweets 200
# User 526, tweets 200
# User 527, tweets 200
# User 528, tweets 200
# User 529, tweets 200
# User 530, tweets 200
# User 531, tweets 200
# User 532, tweets 197
# User 533, tweets 200
# User 534, tweets 200
# User 535, tweets 200
# User 536, tweets 198
# User 537, tweets 200
# User 538, tweets 199
# User 539, tweets 200
# User 540, tweets 200
# User 541, tweets 200
# User 542, tweets 197
# User 543, tweets 200
# User 544, tweets 200
# User 545, tweets 200
# User 546, tweets 199
# User 547, tweets 199
# User 548, tweets 197
# User 549, tweets 200
# User 550, tweets 200
# User 551, tweets 200
# User 552, tweets 200
# User 553, tweets 200
# User 554, tweets 199
# User 555, tweets 200
# User 556, tweets 200
# User 557, tweets 199
# User 558, tweets 200
# User 559, tweets 200
# User 560, tweets 198
# User 561, tweets 200
# User 562, tweets 200
# User 563, tweets 199
# User 564, tweets 200
# User 565, tweets 200
# User 566, tweets 200
# User 567, tweets 200
# User 568, tweets 200
# User 569, tweets 200
# User 570, tweets 198
# User 571, tweets 200
# User 572, tweets 200
# User 573, tweets 200
# User 574, tweets 199
# User 575, tweets 200
# User 576, tweets 199
# User 577, tweets 200
# User 578, tweets 200
# User 579, tweets 200
# User 580, tweets 200
# User 581, tweets 199
# User 582, tweets 200
# User 583, tweets 200
# User 584, tweets 200
# User 585, tweets 199
# User 586, tweets 200
# User 587, tweets 200
# User 588, tweets 200
# User 589, tweets 200
# User 590, tweets 199
# User 591, tweets 200
# User 592, tweets 197
# User 593, tweets 200
# User 594, tweets 200
# User 595, tweets 200
# User 596, tweets 200
# User 597, tweets 200
# User 598, tweets 200
# User 599, tweets 200
# User 600, tweets 200
# User 601, tweets 200
# User 602, tweets 200
# User 603, tweets 198
# User 604, tweets 200
# User 605, tweets 200
# User 606, tweets 200
# User 607, tweets 198
# User 608, tweets 199
# User 609, tweets 200
# User 610, tweets 200
# User 611, tweets 200
# User 612, tweets 200
# User 613, tweets 200
# User 614, tweets 200
# User 615, tweets 200
# User 616, tweets 200
# User 617, tweets 200
# User 618, tweets 200
# User 619, tweets 200
# User 620, tweets 200
# User 621, tweets 200
# User 622, tweets 200
# User 623, tweets 200
# User 624, tweets 197
# User 625, tweets 195
# User 626, tweets 200
# User 627, tweets 200
# User 628, tweets 200
# User 629, tweets 199
# User 630, tweets 200
# User 631, tweets 200
# User 632, tweets 200
# User 633, tweets 200
# User 634, tweets 200
# User 635, tweets 200
# User 636, tweets 200
# User 637, tweets 200
# User 638, tweets 199
# User 639, tweets 200
# User 640, tweets 200
# User 641, tweets 200
# User 642, tweets 198
# User 643, tweets 199
# User 644, tweets 200
# User 645, tweets 200
# User 646, tweets 199
# User 647, tweets 199
# User 648, tweets 197
# User 649, tweets 199
# User 650, tweets 200
# User 651, tweets 198
# User 652, tweets 200
# User 653, tweets 200
# User 654, tweets 199
# User 655, tweets 200
# User 656, tweets 199
# User 657, tweets 200
# User 658, tweets 200
# User 659, tweets 200
# User 660, tweets 200
# User 661, tweets 200
# User 662, tweets 200
# User 663, tweets 200
# User 664, tweets 200
# User 665, tweets 198
# User 666, tweets 200
# User 667, tweets 198
# User 668, tweets 200
# User 669, tweets 200
# User 670, tweets 200
# User 671, tweets 200
# User 672, tweets 199
# User 673, tweets 200
# User 674, tweets 200
# User 675, tweets 200
# User 676, tweets 200
# User 677, tweets 2
# User 678, tweets 200
# User 679, tweets 196
# User 680, tweets 200
# User 681, tweets 200
# User 682, tweets 200
# User 683, tweets 200
# User 684, tweets 200
# User 685, tweets 200
# User 686, tweets 199
# User 687, tweets 199
# User 688, tweets 200
# User 689, tweets 200
# User 690, tweets 200
# User 691, tweets 200
# User 692, tweets 200
# User 693, tweets 200
# User 694, tweets 200
# User 695, tweets 199
# User 696, tweets 200
# User 697, tweets 196
# User 698, tweets 200
# User 699, tweets 200
# User 700, tweets 71
# User 701, tweets 200
# User 702, tweets 200
# User 703, tweets 200
# User 704, tweets 200
# User 705, tweets 200
# User 706, tweets 200
# User 707, tweets 200
# User 708, tweets 200
# User 709, tweets 200
# User 710, tweets 200
# User 711, tweets 200
# User 712, tweets 200
# User 713, tweets 200
# User 714, tweets 200
# User 715, tweets 197
# User 716, tweets 198
# User 717, tweets 200
# User 718, tweets 200
# User 719, tweets 200
# User 720, tweets 200
# User 721, tweets 197
# User 722, tweets 199
# User 723, tweets 200
# User 724, tweets 200
# User 725, tweets 200
# User 726, tweets 157
# User 727, tweets 198
# User 728, tweets 200
# User 729, tweets 200
# User 730, tweets 200
# User 731, tweets 200
# User 732, tweets 200
# User 733, tweets 200
# User 734, tweets 200
# User 735, tweets 6
# User 736, tweets 199
# User 737, tweets 200
# User 738, tweets 198
# User 739, tweets 200
# User 740, tweets 200
# User 741, tweets 200
# User 742, tweets 199
# User 743, tweets 200
# User 744, tweets 200
# User 745, tweets 199
# User 746, tweets 200
# User 747, tweets 200
# User 748, tweets 199
# User 749, tweets 200
# User 750, tweets 200
# User 751, tweets 200
# User 752, tweets 200
# User 753, tweets 198
# User 754, tweets 200
# User 755, tweets 200
# User 756, tweets 200
# User 757, tweets 200
# User 758, tweets 200
# User 759, tweets 200
# User 760, tweets 200
# User 761, tweets 200
# User 762, tweets 200
# User 763, tweets 198
# User 764, tweets 200
# User 765, tweets 200
# User 766, tweets 200
# User 767, tweets 200
# User 768, tweets 200
# User 769, tweets 200
# User 770, tweets 192
# User 771, tweets 200
# User 772, tweets 200
# User 773, tweets 200
# User 774, tweets 200
# User 775, tweets 200
# User 776, tweets 200
# User 777, tweets 200
# User 778, tweets 200
# User 779, tweets 200
# User 780, tweets 200
# User 781, tweets 200
# User 782, tweets 200
# User 783, tweets 198
# User 784, tweets 199
# User 785, tweets 200
# User 786, tweets 200
# User 787, tweets 200
# User 788, tweets 200
# User 789, tweets 200
# User 790, tweets 200
# User 791, tweets 200
# User 792, tweets 200
# User 793, tweets 200
# User 794, tweets 200
# User 795, tweets 193
# User 796, tweets 200
# User 797, tweets 200
# User 798, tweets 200
# User 799, tweets 200
# User 800, tweets 200
# User 801, tweets 200
# User 802, tweets 200
# User 803, tweets 200
# User 804, tweets 199
# User 805, tweets 200
# User 806, tweets 199
# User 807, tweets 200
# User 808, tweets 199
# User 809, tweets 200
# User 810, tweets 200
# User 811, tweets 200
# User 812, tweets 200
# User 813, tweets 200
# User 814, tweets 200
# User 815, tweets 200
# User 816, tweets 200
# User 817, tweets 199
# User 818, tweets 200
# User 819, tweets 199
# User 820, tweets 200
# User 821, tweets 200
# User 822, tweets 199
# User 823, tweets 200
# User 824, tweets 200
# User 825, tweets 200
# User 826, tweets 192
# User 827, tweets 200
# User 828, tweets 200
# User 829, tweets 200
# User 830, tweets 200
# User 831, tweets 200
# User 832, tweets 200
# User 833, tweets 200
# User 834, tweets 200
# User 835, tweets 200
# User 836, tweets 200
# User 837, tweets 200
# User 838, tweets 200
# User 839, tweets 200
# User 840, tweets 200
# User 841, tweets 200
# User 842, tweets 200
# User 843, tweets 200
# User 844, tweets 200
# User 845, tweets 195
# User 846, tweets 200
# User 847, tweets 200
# User 848, tweets 200
# User 849, tweets 200
# User 850, tweets 200
# User 851, tweets 200
# User 852, tweets 200
# User 853, tweets 198
# User 854, tweets 200
# User 855, tweets 199
# User 856, tweets 200
# User 857, tweets 200
# User 858, tweets 200
# User 859, tweets 200
# User 860, tweets 200
# User 861, tweets 198
# User 862, tweets 200
# User 863, tweets 200
# User 864, tweets 200
# User 865, tweets 199
# User 866, tweets 200
# User 867, tweets 200
# User 868, tweets 200
# User 869, tweets 200
# User 870, tweets 200
# User 871, tweets 199
# User 872, tweets 200
# User 873, tweets 200
# User 874, tweets 200
# User 875, tweets 198
# User 876, tweets 200
# User 877, tweets 200
# User 878, tweets 200
# User 879, tweets 200
# User 880, tweets 200
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-e1366fb9e52e> in <module>()
#       8             t = json.loads("["+tweets[:-1])
#       9         else:
# ---> 10             t = json.loads("["+tweets+"]")
#      11         good.append(t)
#      12         print "User %s, tweets %s" % (i, len(t))
#
# C:\Python27\lib\json\__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     336             parse_int is None and parse_float is None and
#     337             parse_constant is None and object_pairs_hook is None and not kw):
# --> 338         return _default_decoder.decode(s)
#     339     if cls is None:
#     340         cls = JSONDecoder
#
# C:\Python27\lib\json\decoder.pyc in decode(self, s, _w)
#     367         end = _w(s, end).end()
#     368         if end != len(s):
# --> 369             raise ValueError(errmsg("Extra data", s, end, len(s)))
#     370         return obj
#     371
#
# ValueError: Extra data: line 1 column 745069 - line 1 column 745071 (char 745068 - 745070)
# User 881, tweets 200

# %%
print len(good)
print good[0]
# Out:
# 882
# [{u'contributors': None, u'truncated': False, u'text': u'And this one comes from the library\u2026\n\nSix hard-cover volumes from the Collected Works of Hugh Nibley and a... http://t.co/XOp6o7MhWL', u'in_reply_to_status_id': None, u'id': 527212032597037056L, u'favorite_count': 0, u'source': u'<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>', u'retweeted': False, u'coordinates': None, u'entities': {u'symbols': [], u'user_mentions': [], u'hashtags': [], u'urls': [{u'url': u'http://t.co/XOp6o7MhWL', u'indices': [110, 132], u'expanded_url': u'http://fb.me/6B2ibP2Wo', u'display_url': u'fb.me/6B2ibP2Wo'}]}, u'in_reply_to_screen_name': None, u'id_str': u'527212032597037056', u'retweet_count': 0, u'in_reply_to_user_id': None, u'favorited': False, u'user': {u'follow_request_sent': False, u'profile_use_background_image': False, u'profile_text_color': u'666666', u'id': 614, u'verified': False, u'profile_location': None, u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/465965547855679488/ONqxqGvL_normal.jpeg', u'profile_sidebar_fill_color': u'252429', u'is_translator': False, u'geo_enabled': True, u'entities': {u'url': {u'urls': [{u'url': u'http://t.co/x5Vr8HWFxj', u'indices': [0, 22], u'expanded_url': u'http://facebook.com/christian.harrison', u'display_url': u'facebook.com/christian.harr\u2026'}]}, u'description': {u'urls': []}}, u'followers_count': 1377, u'protected': False, u'location': u'Salt Lake City, UT', u'default_profile_image': False, u'id_str': u'614', u'lang': u'en', u'utc_offset': 12600, u'statuses_count': 7894, u'description': u'Urban enthusiast, professional storyteller, man of faith.', u'friends_count': 1931, u'profile_link_color': u'2FC2EF', u'profile_image_url': u'http://pbs.twimg.com/profile_images/465965547855679488/ONqxqGvL_normal.jpeg', u'notifications': False, u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme9/bg.gif', u'profile_background_color': u'1A1B1F', u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/614/1365311832', u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme9/bg.gif', u'screen_name': u'dcharrison', u'is_translation_enabled': False, u'profile_background_tile': False, u'favourites_count': 83, u'name': u'Christian Harrison', u'url': u'http://t.co/x5Vr8HWFxj', u'created_at': u'Thu Jul 13 20:30:05 +0000 2006', u'contributors_enabled': False, u'time_zone': u'Tehran', u'profile_sidebar_border_color': u'000000', u'default_profile': False, u'following': False, u'listed_count': 39}, u'geo': None, u'in_reply_to_user_id_str': None, u'possibly_sensitive': False, u'lang': u'en', u'created_at': u'Tue Oct 28 21:35:18 +0000 2014', u'in_reply_to_status_id_str': None, u'place': None}, {u'contributors': None, u'truncated': False, u'text': u'Another round of house-cleaning treasure!\n\nI have a vintage ceramic Japanese headrest (mid-twentieth century) for... http://t.co/Y9I6Su3m0z', u'in_reply_to_status_id': None, u'id': 527210737530195968L, u'favorite_count': 0, u'source': u'<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>', u'retweeted': False, u'coordinates': None, u'entities': {u'symbols': [], u'user_mentions': [], u'hashtags': [], u'urls': [{u'url': u'http://t.co/Y9I6Su3m0z', u'indices': [117, 139], u'expanded_url': u'http://fb.me/6VPTwWGbo', u'display_url': u'fb.me/6VPTwWGbo'}]}, u'in_reply_to_screen_name': None, u'id_str': u'527210737530195968', u'retweet_count': 0, u'in_reply_to_user_id': None, u'favorited': False, u'user': {u'follow_request_sent': False, u'profile_use_background_image': False, u'profile_text_color': u'666666', u'id': 614, u'verified': False, u'profile_location': None, u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/465965547855679488/ONqxqGvL_normal.jpeg', u'profile_sidebar_fill_color': u'252429', u'is_translator': False, u'geo_enabled': True, u'entities': {u'url': {u'urls': [{u'url': u'http://t.co/x5Vr8HWFxj', u'indices': [0, 22], u'expanded_url ...

# %%
f2 = open(data_path + "/bots.json")
for line2 in f2:
    bots = line2.split("]][[")
#     print bots[0]
    last = len(bots)

print "Total %s users" % last
# Out:
# Total 898 users

# %%
from collections import Counter

bts = Counter()
for i,tweets in enumerate(bots):
    if i == 0:
        t = json.loads(tweets[1:] + "]")
    elif i == (last-1):
        t = json.loads("["+tweets[:-1])
    else:
        t = json.loads("["+tweets+"]")
    bts.update([len(t)])
#         print "User %s, tweets %s" % (i, len(t))

# %%
import numpy as np
print bts.most_common(4)
# Out:
# [(200, 728), (199, 61), (198, 14), (197, 13)]

# %%
import numpy as np

print sum(bts)
print sum(bts.values())
print 1. * np.multiply(np.array(bts.values()),np.array(bts.keys())).sum() / sum(bts)
# Out:
# 6617
# 898
# 25.9848874112

# %%
print np.array(bts.keys())
# Out:
# [192   3   5   6 135 136   9  12  14  15  16 147 148  21 150  25  69  31
#  161  34  35   1  70  65  40 169  43  46 176  49  51 180 182  55  56 186
#  187 190 191  64 193 195 196 197 198 199 200  74  76  77  79  80  86 101
#   58  94 165 134 102 104  63 106 110 116 123 126]

# %%
import numpy as np
def calibrate_scores(n_scores, bounds=(.5,1)):
    delta = 1.* (bounds[1] - bounds[0]) / (n_scores -1)
    calibrated = (np.ones(n_scores)*bounds[1]) - (np.array(range(n_scores))*delta)
    return calibrated

print calibrate_scores(5)
# Out:
# [ 1.     0.875  0.75   0.625  0.5  ]

# %%
print calibrate_scores(10, bounds=(.5,1))
# Out:
# [ 1.          0.94444444  0.88888889  0.83333333  0.77777778  0.72222222
#   0.66666667  0.61111111  0.55555556  0.5       ]

# %%
a = calibrate_scores(10, bounds=(.5,1)) 
a = np.append(a, calibrate_scores(10, bounds=(1,.5)))
print a
# Out:
# [ 1.          0.94444444  0.88888889  0.83333333  0.77777778  0.72222222
#   0.66666667  0.61111111  0.55555556  0.5         0.5         0.55555556
#   0.61111111  0.66666667  0.72222222  0.77777778  0.83333333  0.88888889
#   0.94444444  1.        ]

# %%
print a.shape
# Out:
# (20L,)

# %%
b = np.random.random((20)) # original p(y=0|x)
order = b.argsort() # sorted
print order
# Out:
# [ 4  8  6  7 19 18 15 11  9 13  1 17  2 14 10  5 16  3  0 12]

# %%
print a[order] # new scores for the ordered instances, this shouldbe return as scores for all sentences
# Out:
# [ 0.77777778  0.55555556  0.66666667  0.61111111  1.          0.94444444
#   0.77777778  0.55555556  0.5         0.66666667  0.94444444  0.88888889
#   0.88888889  0.72222222  0.5         0.72222222  0.83333333  0.83333333
#   1.          0.61111111]
